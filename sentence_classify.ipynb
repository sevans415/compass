# %%
# File for classifying the sentences of articles with labels based solely off of the outlet they were taken from

# %%
import numpy as np
import pandas as pd

# %%
def append_sentences(fname, labels):
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    fp = open(fname)
    data = fp.read()
    #print('\n-----\n'.join(tokenizer.tokenize(data)))
    sentences = tokenizer.tokenize(data)
    sent_df = pd.DataFrame(sentences, labels)
    print sent_df.shape[0]
    return sent_df

# %%
# Generate filenames
sources = ['breit/breit', 'fox/fox', 'new_yorker/new_yorker', 'nyt/nyt', 'cnn/cnn']
nums = [38, 39, 39, 38, 38]
labels = [0.7, 0.3, -0.5, -0.3, -0.1]

def make_fnames(source, num, label, all_articles):
    arts = [('opinion_articles/' + source + str(i) + '.txt', label) for i in range(num)]
    all_articles += arts

articles = []    
for tup in zip(sources, nums, labels):
    make_fnames(tup[0], tup[1], tup[2], articles)

# %%
articles[:5]
# Out:
# [('opinion_articles/breit/breit0.txt', 0.7),
#  ('opinion_articles/breit/breit1.txt', 0.7),
#  ('opinion_articles/breit/breit2.txt', 0.7),
#  ('opinion_articles/breit/breit3.txt', 0.7),
#  ('opinion_articles/breit/breit4.txt', 0.7)]

# %%
# import articles
text_df.to_excel('text_df.xlsx')

# %%
def append_sentences(fname, label):
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    fp = open(fname)
    data = fp.read()
    #print data
    sent_df = pd.DataFrame(data={'sentences':sentences, 'label':label})
    print sent_df.shape[0]
    return sent_df

# %%
append_sentences(articles[0][0], articles[0][1])
# Out:
# 40
#     label                                          sentences
# 0     0.7  to understand the social conservatives dilemma...
# 1     0.7  but if you believe, as they (and i) do, that a...
# 2     0.7  ultimately, however, social conservatives stri...
# 3     0.7  newsletter sign up continue reading the main s...
# 4     0.7  please verify you're not a robot by clicking t...
# 5     0.7                             invalid email address.
# 6     0.7                                   please re-enter.
# 7     0.7      you must select a newsletter to subscribe to.
# 8     0.7  sign up you agree to receive occasional update...
# 9     0.7                         thank you for subscribing.
# 10    0.7                             an error has occurred.
# 11    0.7                            please try again later.
# 12    0.7               view all new york times newsletters.
# 13    0.7  they seem to think, first, that placing origin...
# ...

# %%
labels = np.full(len(sentences), 0.7)

# %%
frames = []
for tup in articles:
    frames.append(append_sentences(tup[0], tup[1]))
# Out:
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40

# %%
new_sentences = pd.concat(frames)

# %%
new_sentences
# Out:
#     label                                          sentences
# 0     0.7  to understand the social conservatives dilemma...
# 1     0.7  but if you believe, as they (and i) do, that a...
# 2     0.7  ultimately, however, social conservatives stri...
# 3     0.7  newsletter sign up continue reading the main s...
# 4     0.7  please verify you're not a robot by clicking t...
# 5     0.7                             invalid email address.
# 6     0.7                                   please re-enter.
# 7     0.7      you must select a newsletter to subscribe to.
# 8     0.7  sign up you agree to receive occasional update...
# 9     0.7                         thank you for subscribing.
# 10    0.7                             an error has occurred.
# 11    0.7                            please try again later.
# 12    0.7               view all new york times newsletters.
# 13    0.7  they seem to think, first, that placing origin...
# ...

# %%
# Function to clean word data--removes stopwords, makes lowercase, removes numbers
import re
from nltk.corpus import stopwords
def clean_words(sentences):
    words_clean = np.full(len(sentences), None)
    for i, words in enumerate(sentences):
        word_list = re.split('\W+', words)
        words1 = [word.lower() for word in word_list if word.lower() not in stopwords.words('english')]
        words2 = [word for word in words1 if not any(char.isdigit() for char in word)]
        words_clean[i] = (' '.join(words2)).strip()
    return words_clean

# %%
new_sentences['clean_sentences'] = clean_words(new_sentences['sentences'])

# %%
new_sentences
# Out:
#     label                                          sentences  \
# 0     0.7  to understand the social conservatives dilemma...
# 1     0.7  but if you believe, as they (and i) do, that a...
# 2     0.7  ultimately, however, social conservatives stri...
# 3     0.7  newsletter sign up continue reading the main s...
# 4     0.7  please verify you're not a robot by clicking t...
# 5     0.7                             invalid email address.
# 6     0.7                                   please re-enter.
# 7     0.7      you must select a newsletter to subscribe to.
# 8     0.7  sign up you agree to receive occasional update...
# 9     0.7                         thank you for subscribing.
# 10    0.7                             an error has occurred.
# 11    0.7                            please try again later.
# 12    0.7               view all new york times newsletters.
# 13    0.7  they seem to think, first, that placing origin...
# ...

# %%
new_sentences_2 = new_sentences[new_sentences['clean_sentences'].map(len) > 15]

# %%
new_sentences_2.shape
# Out:
# (6912, 3)

# %%
# Export for later use
new_sentences_2.to_excel('new_sentences.xlsx')
